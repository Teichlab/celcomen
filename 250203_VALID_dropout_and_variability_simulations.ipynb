# %%
# import relevant packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.stats as ss
import seaborn as sns
from tqdm import tqdm

import torch
import torch_geometric
from torch_geometric.loader import DataLoader

# set figure parameters
sc.settings.set_figure_params(dpi=100)

# %% [markdown]
# ## define helper functions

# %%
# define a function to gather positions
def get_pos(n_x, n_y):
    # create the hex lattice
    xs = np.array([np.arange(0, n_x) + 0.5 if idx % 2 == 0 else np.arange(0, n_x) for idx in range(n_y)])
    # derive the y-step given a distance of one
    y_step = np.sqrt(1**2+0.5**2)
    ys = np.array([[y_step * idy] * n_x for idy in range(n_y)])
    # define the positions
    pos = np.vstack([xs.flatten(), ys.flatten()]).T
    return pos

# %%
# define a function to derive the gex from the sphex
def calc_gex(sphex):
    """
    Calculates the gene expression matrix from the spherical
    """
    # setup the gex
    n_genes = sphex.shape[1]+1
    gex = torch.from_numpy(np.ones((sphex.shape[0], n_genes)).astype('float32'))
    # compute the gex
    for idx in range(n_genes):
        for idx_ in range(idx):
            gex[:,idx] *= torch.sin(sphex[:,idx_])
        if idx < n_genes-1:
            gex[:,idx] *= torch.cos(sphex[:,idx])
    return torch.nan_to_num(gex)

# %%
from torch_geometric.nn import GCNConv
from sklearn.neighbors import kneighbors_graph
# define the number of neighbors (six for visium)
n_neighbors = 6
# define the simcomen class
class simcomen(torch.nn.Module):
    # define initialization function
    def __init__(self, input_dim, output_dim, n_neighbors, seed=0):
        super(simcomen, self).__init__()
        # define the seed
        torch.manual_seed(seed)
        # set up the graph convolution
        self.conv1 = GCNConv(input_dim, output_dim, add_self_loops=False)
        # set up the linear layer for intracellular gene regulation
        self.lin = torch.nn.Linear(input_dim, output_dim)
        # define the neighbors
        self.n_neighbors = n_neighbors
        # define a tracking variable for the gene expression x matrix
        self.sphex = None
        self.gex = None

    # define a function to artificially set the g2g matrix
    def set_g2g(self, g2g):
        """
        Artifically sets the core g2g matrix to be a specified interaction matrix
        """
        # set the weight as the input
        self.conv1.lin.weight = torch.nn.Parameter(g2g, requires_grad=False)
        # and then set the bias as all zeros
        self.conv1.bias = torch.nn.Parameter(torch.from_numpy(np.zeros(n_genes).astype('float32')), requires_grad=False)

    # define a function to artificially set the g2g matrix
    def set_g2g_intra(self, g2g_intra):
        """
        Artifically sets the core g2g intracellular matrix to be a specified matrix
        """
        # set the weight as the input
        self.lin.weight = torch.nn.Parameter(g2g_intra, requires_grad=False)
        # and then set the bias as all zeros
        self.lin.bias = torch.nn.Parameter(torch.from_numpy(np.zeros(len(g2g_intra)).astype('float32')), requires_grad=False)

    # define a function to artificially set the sphex matrix
    def set_sphex(self, sphex):
        """
        Artifically sets the current sphex matrix
        """
        self.sphex = torch.nn.Parameter(sphex, requires_grad=True)
        
    # define the forward pass
    def forward(self, edge_index, batch):
        """
        Forward pass for prediction or training,
        convolutes the input by the expected interactions and returns log(Z_mft)
        """
        # compute the gex
        self.gex = calc_gex(self.sphex)
        # compute the message
        msg = self.conv1(self.gex, edge_index)
        # compute intracellular message
        msg_intra = self.lin(self.gex)
        # compute the log z mft
        log_z_mft = self.log_Z_mft(edge_index, batch)
        return msg, msg_intra, log_z_mft

    # define approximation function
    def log_Z_mft(self, edge_index, batch):
        """
        Mean Field Theory approximation to the partition function. Assumptions used are:
        - expression of values of genes are close to their mean values over the visium slide
        - \sum_b g_{a,b} m^b >0 \forall a, where m is the mean gene expression and g is the gene-gene
          interaction matrix.
        """
        # retrieve number of spots
        num_spots = self.gex.shape[0]
        # calculate mean gene expression        
        mean_genes = torch.mean(self.gex, axis=0).reshape(-1,1)  # the mean should be per connected graph
        # calculate the norm of the sum of mean genes
        g = torch.norm(torch.mm( self.n_neighbors*self.conv1.lin.weight + 2*self.lin.weight, mean_genes))   # maybe needs to change to g = torch.norm(torch.mm(mean_genes, self.conv1.lin.weight))
        # calculate the contribution for mean values        
        z_mean = - num_spots  * torch.mm(torch.mm(torch.t(mean_genes), self.lin.weight + 0.5 * self.n_neighbors * self.conv1.lin.weight),  mean_genes)
        # calculate the contribution gene interactions
        z_interaction = self.z_interaction(num_spots=num_spots, g=g)
        # add the two contributions        
        log_z_mft = z_mean + z_interaction
        return log_z_mft

    def z_interaction(self, num_spots, g):
        """
        Avoid exploding exponentials by returning an approximate interaction term for the partition function.
        """
        if g>20:
            z_interaction = num_spots * ( g - torch.log( g) )
        else:
            z_interaction = num_spots * torch.log((torch.exp( g) - torch.exp(- g))/( g))
        return z_interaction

# %%
# define the celcomen class
class celcomen(torch.nn.Module):
    # define initialization function
    def __init__(self, input_dim, output_dim, n_neighbors, seed=0):
        super(celcomen, self).__init__()
        # define the seed
        torch.manual_seed(seed)
        # set up the graph convolution
        self.conv1 = GCNConv(input_dim, output_dim, add_self_loops=False)
        # set up the linear layer for intracellular gene regulation
        self.lin = torch.nn.Linear(input_dim, output_dim)
        # define the neighbors
        self.n_neighbors = n_neighbors
        # define a tracking variable for the gene expression x matrix
        self.gex = None

    # define a function to artificially set the g2g matrix
    def set_g2g(self, g2g):
        """
        Artifically sets the core g2g matrix to be a specified interaction matrix
        """
        # set the weight as the input
        self.conv1.lin.weight = torch.nn.Parameter(g2g, requires_grad=True)
        # and then set the bias as all zeros
        self.conv1.bias = torch.nn.Parameter(torch.from_numpy(np.zeros(len(g2g)).astype('float32')), requires_grad=False)

    # define a function to artificially set the g2g matrix
    def set_g2g_intra(self, g2g_intra):
        """
        Artifically sets the core g2g intracellular matrix to be a specified matrix
        """
        # set the weight as the input
        self.lin.weight = torch.nn.Parameter(g2g_intra, requires_grad=True)
        # and then set the bias as all zeros
        self.lin.bias = torch.nn.Parameter(torch.from_numpy(np.zeros(len(g2g_intra)).astype('float32')), requires_grad=False)

    # define a function to artificially set the sphex matrix
    def set_gex(self, gex):
        """
        Artifically sets the current sphex matrix
        """
        self.gex = torch.nn.Parameter(gex, requires_grad=False)
        
    # define the forward pass
    def forward(self, edge_index, batch):
        """
        Forward pass for prediction or training,
        convolutes the input by the expected interactions and returns log(Z_mft)
        """
        # compute the message
        msg = self.conv1(self.gex, edge_index)
        # compute intracellular message
        msg_intra = self.lin(self.gex)
        # compute the log z mft
        log_z_mft = self.log_Z_mft(edge_index, batch)
        return msg, msg_intra, log_z_mft

    # define approximation function
    def log_Z_mft(self, edge_index, batch):
        """
        Mean Field Theory approximation to the partition function. Assumptions used are:
        - expression of values of genes are close to their mean values over the visium slide
        - \sum_b g_{a,b} m^b >0 \forall a, where m is the mean gene expression and g is the gene-gene
          interaction matrix.
        """
        # retrieve number of spots
        num_spots = self.gex.shape[0]
        # calculate mean gene expression        
        mean_genes = torch.mean(self.gex, axis=0).reshape(-1,1)  # the mean should be per connected graph
        # calculate the norm of the sum of mean genes
        g = torch.norm(torch.mm( self.n_neighbors*self.conv1.lin.weight + 2*self.lin.weight, mean_genes))   # maybe needs to change to g = torch.norm(torch.mm(mean_genes, self.conv1.lin.weight))
        # calculate the contribution for mean values        
        z_mean = - num_spots  * torch.mm(torch.mm(torch.t(mean_genes), self.lin.weight + 0.5 * self.n_neighbors * self.conv1.lin.weight),  mean_genes)
        # calculate the contribution gene interactions
        z_interaction = self.z_interaction(num_spots=num_spots, g=g)
        # add the two contributions        
        log_z_mft = z_mean + z_interaction
        return log_z_mft

    def z_interaction(self, num_spots, g):
        """
        Avoid exploding exponentials by returning an approximate interaction term for the partition function.
        """
        if g>20:
            z_interaction = num_spots * ( g - torch.log( g) )
        else:
            z_interaction = num_spots * torch.log((torch.exp( g) - torch.exp(- g))/( g))
        return z_interaction

# %%
# define a function to normalize the g2g
def normalize_g2g(g2g):
    """
    Addresses any small fluctuations in symmetrical weights
    """
    # symmetrize the values
    g2g = (g2g + g2g.T) / 2
    # force them to be between 0-1
    g2g[g2g < 0] = 0
    g2g[g2g > 1] = 1
    # force the central line to be 1
    for idx in range(len(g2g)):
        g2g[idx, idx] = 1
    return g2g

# %% [markdown]
# ## perform simulations

# %%
def run_scc(input_g2g, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    zmft_scalar = params[4]
    seed = params[5]
    epochs = params[6]
    # instantiate the model, input and output will be the same
    model = simcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    # artifically set the g2g matrix
    model.set_g2g(input_g2g)
    model.set_g2g_intra(input_g2g)

    # initialize a gene expression matrix
    input_sphex = np.random.normal(np.pi, np.pi/2, size=(pos.shape[0], n_genes-1)).astype('float32')
    model.set_sphex(torch.from_numpy(input_sphex.copy()))
    # set up the optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model(edge_index, 1)
        if epoch == 0:
            input_gex, input_msg = model.gex.clone().detach().numpy(), msg.clone().detach().numpy()
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    output_gex = model.gex.detach().numpy()
    output_msg = msg.detach().numpy()
    exp_g2g = input_g2g.detach().numpy()
    # plot the correlations
    if plot:
        for matrix in [input_gex, input_msg, output_gex, output_msg]:
            g = sns.clustermap(pd.DataFrame(matrix).corr(method='spearman'), cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                               figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
            g.ax_heatmap.grid(False)
            g.ax_cbar.grid(False)
            g.ax_heatmap.tick_params(labelrotation=0)
        # plot the expected g2g matrix
        g = sns.clustermap(exp_g2g, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
        
    return losses, input_gex, output_gex, exp_g2g

# %%
def run_ccc_from_scc(output_gex, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    zmft_scalar = params[4]
    seed = params[5]
    epochs = params[6]
    
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    
    # instantiate the model, input and output will be the same
    model_rev = celcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # artifically set the g2g matrix
    input_g2g = np.random.uniform(size=(n_genes, n_genes)).astype('float32')
    input_g2g = normalize_g2g((input_g2g + input_g2g.T) / 2)
    model_rev.set_g2g(torch.from_numpy(input_g2g))
    model_rev.set_g2g_intra(torch.from_numpy(input_g2g))
    # initialize a gene expression matrix
    model_rev.set_gex(torch.from_numpy(output_gex))
    
    # setup the initial optimizer
    optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model_rev.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model_rev(edge_index, 1)
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model_rev.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model_rev.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        # repeatedly force a normalization
        model_rev.conv1.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.conv1.lin.weight), requires_grad=True)
        model_rev.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.lin.weight), requires_grad=True)
        optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
        
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    obs_g2g_ccc = model_rev.conv1.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_ccc, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
    obs_g2g_intra = model_rev.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_intra, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)

    return losses, obs_g2g_ccc, obs_g2g_intra

# %%
# define a function to generate a random g2g interaction matrix
def gen_g2g(n_genes):
    # sample the interaction terms and guarantee at least one interaction
    p = ss.uniform.rvs(size=1)[0]
    intrxns = [0]
    # we continously sample until we get interactions that do are not all empty or full
    while (np.mean(intrxns) == 0.0) | (np.mean(intrxns) == 1.0):
        intrxns = ss.binom.rvs(1, p, size=sum(list(range(n_genes))))
    # fill in the input g2g with the appropriate terms
    input_g2g = np.ones((n_genes, n_genes)).astype('float32')
    idz = 0
    for idx in range(n_genes-1):
        for idy in range(idx+1, n_genes):
            input_g2g[idx, idy] = intrxns[idz]
            input_g2g[idy, idx] = intrxns[idz]
            idz += 1
    input_g2g = torch.tensor(input_g2g)
    return input_g2g

# %%
def run_sim(params):
    # unpack the parameters
    n_x, n_y, n_genes, learning_rate, zmft_scalar, seed, epochs = params
    # set the seed
    np.random.seed(seed)
    # define the input g2g
    input_g2g = gen_g2g(n_genes)
    # run the simulation
    losses_scc, input_gex, output_gex, exp_g2g = run_scc(input_g2g, params)

    # define results from ccc
    losses_ccc, obs_g2g_ccc, obs_g2g_intra = run_ccc_from_scc(output_gex, params)
    obs_g2g = obs_g2g_ccc.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_ccc = results.copy()

    # define results from ccc
    obs_g2g = obs_g2g_intra.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_intra = results.copy()
    
    return results_ccc, results_intra, losses_scc, losses_ccc

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for zmft_scalar in np.arange(0, 1+.1, .1):
    zmft_scalar = round(zmft_scalar, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, zmft_scalar, 0, 50])[-1]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=zmft_scalar)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Celcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')
# Out:
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for zmft_scalar in np.arange(0, 1+.1, .1):
    zmft_scalar = round(zmft_scalar, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, zmft_scalar, 0, 50])[-2]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=zmft_scalar)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Simcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')
# Out:
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())

# %%
import multiprocessing as mp
from tqdm import tqdm
# define the parameters
n_x, n_y, n_genes = 10, 10, 4
learning_rate = 1e-1
zmft_scalar = 1e-1
epochs = 50
# define the parameters
n_sims = 100
params_list = [[n_x, n_y, n_genes, learning_rate, zmft_scalar, seed, epochs] for seed in range(n_sims)]
# run the simulations
results_list = []
with mp.Pool(5) as pool:
    for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
        results_list.append(results)
# Out:
#   6%|██▌                                        | 6/100 [00:00<00:06, 13.76it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.01it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.25it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.90it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.15it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.40it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.56it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.79it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.72it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.77it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.49it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.40it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.51it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.65it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.70it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.80it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.79it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.36it/s]

# %%
# define the order of the metrics
order = ['loss_scc','loss_ccc',
         'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
         'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
         'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

# %%
# define the things we wish to plot
plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
            ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

# %%
# melt the dataframe into a plottable function (complete this for CCC as before)
data = results_ccc.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %%
# melt the dataframe into a plottable function (complete this for intra for newly defined method)
data = results_intra.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %% [markdown]
# ### repeat with eight genes

# %%
# define hyperparameters
n_genes = 8
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for zmft_scalar in np.arange(0, 1+.1, .1):
    zmft_scalar = round(zmft_scalar, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, zmft_scalar, 0, 50])[-1]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=zmft_scalar)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Celcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')
# Out:
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())

# %%
# define hyperparameters
n_genes = 8
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for zmft_scalar in np.arange(0, 1+.1, .1):
    zmft_scalar = round(zmft_scalar, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, zmft_scalar, 0, 50])[-2]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=zmft_scalar)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Simcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')
# Out:
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())

# %%
import multiprocessing as mp
from tqdm import tqdm
# define the parameters
n_x, n_y, n_genes = 10, 10, 8
learning_rate = 1e-1
zmft_scalar = 1e-1
epochs = 50
# define the parameters
n_sims = 100
params_list = [[n_x, n_y, n_genes, learning_rate, zmft_scalar, seed, epochs] for seed in range(n_sims)]
# run the simulations
results_list = []
with mp.Pool(5) as pool:
    for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
        results_list.append(results)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:07<00:00, 12.74it/s]

# %%
# define the order of the metrics
order = ['loss_scc','loss_ccc',
         'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
         'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
         'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

# %%
# define the things we wish to plot
plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
            ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

# %%
# melt the dataframe into a plottable function (complete this for CCC as before)
data = results_ccc.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %%
# melt the dataframe into a plottable function (complete this for intra for newly defined method)
data = results_intra.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %% [markdown]
# ### repeat with eight genes zmft of 0.5

# %%
import multiprocessing as mp
from tqdm import tqdm
# define the parameters
n_x, n_y, n_genes = 10, 10, 8
learning_rate = 1e-1
zmft_scalar = 5e-1
epochs = 50
# define the parameters
n_sims = 100
params_list = [[n_x, n_y, n_genes, learning_rate, zmft_scalar, seed, epochs] for seed in range(n_sims)]
# run the simulations
results_list = []
with mp.Pool(5) as pool:
    for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
        results_list.append(results)
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:03<00:05, 12.59it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:05<00:02, 12.87it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:06<00:01, 12.73it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:07<00:00, 12.62it/s]

# %%
# define the order of the metrics
order = ['loss_scc','loss_ccc',
         'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
         'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
         'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

# %%
# define the things we wish to plot
plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
            ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
            ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

# %%
# melt the dataframe into a plottable function (complete this for CCC as before)
data = results_ccc.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/3718937763.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %%
# melt the dataframe into a plottable function (complete this for intra for newly defined method)
data = results_intra.reset_index().melt(id_vars='index')
data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
# run through all of the plots
for metric, value, datasets in plotters:
    # plot key pairwise metrics
    fig, ax = plt.subplots(figsize=[2, 3])
    ax.grid(False)
    ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
                     saturation=1, ax=ax, order=datasets, linecolor='k', linewidth=2, palette=['#cc78bc','#fbafe4'])
    ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
                       ax=ax, order=datasets, edgecolor='k', linewidth=1, jitter=0.25, alpha=0.5, palette=['#cc78bc','#fbafe4'])
    ax.tick_params(axis='x', labelrotation=90)
    if value == 'nlog10p1en4_value':
        ax.set_ylabel(f'-log10({metric}+1e-4)')
    else:
        ax.set_ylabel(f'{metric}')
    # derive the values
    x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
    x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
    mask = (~x1.isna()) & (~x2.isna())
    x1, x2 = x1.loc[mask], x2.loc[mask]
    for idx in x1.index:
        ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
    # derive the p-value
    pval1 = ss.wilcoxon(x1, x2)[1]
    pval2 = ss.ttest_rel(x1, x2)[1]
    text = 'wilcoxon paired p = %.3e' % pval1
    text += '\nt-test paired p = %.3e' % pval2
    ax.text(1.03, .99, text, va='top', ha='left', transform=ax.transAxes)
    ax.set_xlim(-1, 2)
# Out:
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=0,
# /loc/scratch/7949135/ipykernel_16759/911700619.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.stripplot(x='dataset', y=value, data=data.loc[data['metric'] == metric], zorder=2,

# %% [markdown]
# ### check scaling by zmft

# %%
import multiprocessing as mp
from tqdm import tqdm
# loop through zmft scalar values
df_stats = []
for zmft_scalar in np.arange(0, 1+.1, .1):
    # define the parameters
    n_x, n_y, n_genes = 10, 10, 4
    learning_rate = 1e-1
    epochs = 50
    # define the parameters
    n_sims = 100
    params_list = [[n_x, n_y, n_genes, learning_rate, zmft_scalar, seed, epochs] for seed in range(n_sims)]
    # run the simulations
    results_list = []
    with mp.Pool(5) as pool:
        for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
            results_list.append(results)

    # define the order of the metrics
    order = ['loss_scc','loss_ccc',
             'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
             'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
             'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
    results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
    results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

    # define the things we wish to plot
    plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
                ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

    # melt the dataframe into a plottable function (complete this for CCC as before)
    data = results_ccc.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    df_stat = pd.DataFrame(columns=['metric','value','dataset0','dataset1','pval','diff','source'])
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'ccc'

    # melt the dataframe into a plottable function (complete this for intra for newly defined method)
    data = results_intra.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'intra'
    df_stat['zmft_scalar'] = zmft_scalar
    df_stats.append(df_stat)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.07it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.45it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.65it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.24it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.84it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.25it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.15it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.22it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.83it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.66it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.62it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.48it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.63it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.61it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.60it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.58it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.46it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.25it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   1%|▍                                          | 1/100 [00:00<00:24,  4.06it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.10it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:04, 17.82it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  16%|██████▋                                   | 16/100 [00:00<00:04, 19.42it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.13it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.37it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.08it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.31it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.22it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.71it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.80it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.55it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.44it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.13it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 21.44it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.48it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.68it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.30it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.65it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.81it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.16it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   1%|▍                                          | 1/100 [00:00<00:24,  4.11it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.05it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 16.97it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.06it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.67it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.77it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.26it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.42it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.11it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.25it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.87it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.70it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.54it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 21.43it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.54it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.58it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.16it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.56it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.46it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.21it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   1%|▍                                          | 1/100 [00:00<00:26,  3.76it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.34it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.50it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# ...
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.02it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.71it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.95it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.14it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.16it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.24it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.52it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.39it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.54it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.67it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 21.51it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.53it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  80%|█████████████████████████████████▌        | 80/100 [00:03<00:00, 24.41it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  83%|██████████████████████████████████▊       | 83/100 [00:03<00:00, 22.62it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  90%|█████████████████████████████████████▊    | 90/100 [00:04<00:00, 22.18it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  93%|███████████████████████████████████████   | 93/100 [00:04<00:00, 22.32it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 20.55it/s]/loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/1464854921.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.78it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# look at the aggregate
df_stat = pd.concat(df_stats, axis=0)

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'ccc-out')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','zmft_scalar']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['zmft_scalar'].round(1).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Zmft value', ylabel='Input vs. Celcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['zmft_scalar'].round(1).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Zmft value', ylabel='Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Zmft value'),
#  Text(0, 0.5, 'Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'scc-gex-corr')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','zmft_scalar']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['zmft_scalar'].round(1).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Zmft value', ylabel='Input vs. Cel->Simcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['zmft_scalar'].round(1).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Zmft value', ylabel='Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Zmft value'),
#  Text(0, 0.5, 'Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %% [markdown]
# ### check scaling by dropout

# %%
def run_scc(input_g2g, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    dropout_rate = params[4]
    seed = params[5]
    epochs = params[6]
    # instantiate the model, input and output will be the same
    model = simcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    # artifically set the g2g matrix
    model.set_g2g(input_g2g)
    model.set_g2g_intra(input_g2g)

    # initialize a gene expression matrix
    input_sphex = np.random.normal(np.pi, np.pi/2, size=(pos.shape[0], n_genes-1)).astype('float32')
    idxys = [(x, y) for x, y in zip(*np.where((input_sphex == 0) | (input_sphex != 0)))]
    chosen = np.random.choice(range(len(idxys)), size=round(len(idxys)*dropout_rate), replace=False)
    for idx in chosen:
        x, y = idxys[idx]
        input_sphex[x, y] = 0
    model.set_sphex(torch.from_numpy(input_sphex.copy()))
    # set up the optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model(edge_index, 1)
        if epoch == 0:
            input_gex, input_msg = model.gex.clone().detach().numpy(), msg.clone().detach().numpy()
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    output_gex = model.gex.detach().numpy()
    output_msg = msg.detach().numpy()
    exp_g2g = input_g2g.detach().numpy()
    # plot the correlations
    if plot:
        for matrix in [input_gex, input_msg, output_gex, output_msg]:
            g = sns.clustermap(pd.DataFrame(matrix).corr(method='spearman'), cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                               figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
            g.ax_heatmap.grid(False)
            g.ax_cbar.grid(False)
            g.ax_heatmap.tick_params(labelrotation=0)
        # plot the expected g2g matrix
        g = sns.clustermap(exp_g2g, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
        
    return losses, input_gex, output_gex, exp_g2g

# %%
def run_ccc_from_scc(output_gex, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    dropout_rate = params[4]
    seed = params[5]
    epochs = params[6]
    
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    
    # instantiate the model, input and output will be the same
    model_rev = celcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # artifically set the g2g matrix
    input_g2g = np.random.uniform(size=(n_genes, n_genes)).astype('float32')
    input_g2g = normalize_g2g((input_g2g + input_g2g.T) / 2)
    model_rev.set_g2g(torch.from_numpy(input_g2g))
    model_rev.set_g2g_intra(torch.from_numpy(input_g2g))
    # initialize a gene expression matrix
    model_rev.set_gex(torch.from_numpy(output_gex))
    
    # setup the initial optimizer
    optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model_rev.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model_rev(edge_index, 1)
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model_rev.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model_rev.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        # repeatedly force a normalization
        model_rev.conv1.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.conv1.lin.weight), requires_grad=True)
        model_rev.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.lin.weight), requires_grad=True)
        optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
        
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    obs_g2g_ccc = model_rev.conv1.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_ccc, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
    obs_g2g_intra = model_rev.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_intra, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)

    return losses, obs_g2g_ccc, obs_g2g_intra

# %%
def run_sim(params):
    # unpack the parameters
    n_x, n_y, n_genes, learning_rate, dropout_rate, seed, epochs = params
    # set the seed
    np.random.seed(seed)
    # define the input g2g
    input_g2g = gen_g2g(n_genes)
    # run the simulation
    losses_scc, input_gex, output_gex, exp_g2g = run_scc(input_g2g, params)

    # define results from ccc
    losses_ccc, obs_g2g_ccc, obs_g2g_intra = run_ccc_from_scc(output_gex, params)
    obs_g2g = obs_g2g_ccc.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_ccc = results.copy()

    # define results from ccc
    obs_g2g = obs_g2g_intra.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_intra = results.copy()
    
    return results_ccc, results_intra, losses_scc, losses_ccc

# %%
import multiprocessing as mp
from tqdm import tqdm
# loop through zmft scalar values
df_stats = []
zmft_scalar = 1e-1
for dropout_rate in np.arange(0, 1+.1, .1):
    # define the parameters
    n_x, n_y, n_genes = 10, 10, 4
    learning_rate = 1e-1
    epochs = 50
    # define the parameters
    n_sims = 100
    params_list = [[n_x, n_y, n_genes, learning_rate, dropout_rate, seed, epochs] for seed in range(n_sims)]
    # run the simulations
    results_list = []
    with mp.Pool(5) as pool:
        for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
            results_list.append(results)

    # define the order of the metrics
    order = ['loss_scc','loss_ccc',
             'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
             'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
             'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
    results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
    results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

    # define the things we wish to plot
    plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
                ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

    # melt the dataframe into a plottable function (complete this for CCC as before)
    data = results_ccc.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    df_stat = pd.DataFrame(columns=['metric','value','dataset0','dataset1','pval','diff','source'])
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'ccc'

    # melt the dataframe into a plottable function (complete this for intra for newly defined method)
    data = results_intra.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'intra'
    df_stat['dropout_rate'] = dropout_rate
    df_stats.append(df_stat)
# Out:
#   1%|▍                                          | 1/100 [00:00<00:25,  3.92it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 13.72it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.43it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.34it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.95it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.25it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.34it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.57it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.82it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.73it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.61it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.65it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.77it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.80it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.65it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.36it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.71it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.26it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:24,  4.12it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.36it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.14it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.95it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.20it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.12it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.20it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.33it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.64it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.67it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.82it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.69it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.91it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.88it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 22.12it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.37it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:24,  4.08it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.30it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  16%|██████▋                                   | 16/100 [00:00<00:04, 19.25it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.86it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.80it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.28it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.59it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.36it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.90it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.68it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:02<00:01, 21.57it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.72it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.43it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.35it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.45it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.26it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:04, 17.88it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 21.04it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.67it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.53it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.85it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:02<00:01, 22.06it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 22.13it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  95%|███████████████████████████████████████▉  | 95/100 [00:04<00:00, 23.83it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.39it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.02it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.48it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.29it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.87it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.48it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.47it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.38it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.75it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.62it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:03<00:00, 21.21it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  95%|███████████████████████████████████████▉  | 95/100 [00:04<00:00, 23.17it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.03it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  36%|███████████████                           | 36/100 [00:01<00:02, 21.60it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  95%|███████████████████████████████████████▉  | 95/100 [00:04<00:00, 24.89it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.47it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.05it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.09it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.02it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.31it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.50it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.51it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.60it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.95it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.39it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  31%|█████████████                             | 31/100 [00:01<00:03, 21.10it/s]/loc/scratch/7949135/ipykernel_16759/572179457.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.49it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 21.07it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# look at the aggregate
df_stat = pd.concat(df_stats, axis=0)

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'ccc-out')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','dropout_rate']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar((100*tmp['dropout_rate'].round(1)).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Dropout rate (%)', ylabel='Input vs. Celcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar((100*tmp['dropout_rate'].round(1)).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Dropout rate (%)', ylabel='Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Dropout rate (%)'),
#  Text(0, 0.5, 'Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'scc-gex-corr')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','dropout_rate']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar((100*tmp['dropout_rate'].round(1)).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Dropout rate (%)', ylabel='Input vs. Cel->Simcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar((100*tmp['dropout_rate'].round(1)).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Dropout rate (%)', ylabel='Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Dropout rate (%)'),
#  Text(0, 0.5, 'Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for dropout_rate in np.arange(0, 1+.1, .1):
    dropout_rate = round(dropout_rate, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, dropout_rate, 0, 50])[-1]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=f'{round(dropout_rate*100)}%')
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Celcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for dropout_rate in np.arange(0, 1+.1, .1):
    dropout_rate = round(dropout_rate, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, dropout_rate, 0, 50])[-2]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=f'{round(dropout_rate*100)}%')
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Simcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')

# %% [markdown]
# ### check scaling by variability

# %%
def run_scc(input_g2g, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    variability = params[4]
    seed = params[5]
    epochs = params[6]
    # instantiate the model, input and output will be the same
    model = simcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    # artifically set the g2g matrix
    model.set_g2g(input_g2g)
    model.set_g2g_intra(input_g2g)

    # initialize a gene expression matrix
    input_sphex = np.random.normal(np.pi, variability, size=(pos.shape[0], n_genes-1)).astype('float32')
    model.set_sphex(torch.from_numpy(input_sphex.copy()))
    # set up the optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model(edge_index, 1)
        if epoch == 0:
            input_gex, input_msg = model.gex.clone().detach().numpy(), msg.clone().detach().numpy()
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    output_gex = model.gex.detach().numpy()
    output_msg = msg.detach().numpy()
    exp_g2g = input_g2g.detach().numpy()
    # plot the correlations
    if plot:
        for matrix in [input_gex, input_msg, output_gex, output_msg]:
            g = sns.clustermap(pd.DataFrame(matrix).corr(method='spearman'), cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                               figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
            g.ax_heatmap.grid(False)
            g.ax_cbar.grid(False)
            g.ax_heatmap.tick_params(labelrotation=0)
        # plot the expected g2g matrix
        g = sns.clustermap(exp_g2g, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
        
    return losses, input_gex, output_gex, exp_g2g

# %%
def run_ccc_from_scc(output_gex, params, plot=False):
    # define the hyperparameters
    n_x, n_y, n_genes = params[:3]
    learning_rate = params[3]
    variability = params[4]
    seed = params[5]
    epochs = params[6]
    
    # retrieve the positions
    pos = torch.from_numpy(get_pos(n_x, n_y).astype('float32'))
    # find the edges via kneighbors, not including self because we are considering intercellular
    edge_index = kneighbors_graph(pos, n_neighbors, include_self=False).todense()
    edge_index = torch.from_numpy(np.array(np.where(edge_index)))
    
    # instantiate the model, input and output will be the same
    model_rev = celcomen(input_dim=n_genes, output_dim=n_genes, n_neighbors=n_neighbors, seed=seed)
    
    # now perform the simulation
    np.random.seed(seed)
    # artifically set the g2g matrix
    input_g2g = np.random.uniform(size=(n_genes, n_genes)).astype('float32')
    input_g2g = normalize_g2g((input_g2g + input_g2g.T) / 2)
    model_rev.set_g2g(torch.from_numpy(input_g2g))
    model_rev.set_g2g_intra(torch.from_numpy(input_g2g))
    # initialize a gene expression matrix
    model_rev.set_gex(torch.from_numpy(output_gex))
    
    # setup the initial optimizer
    optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
    # keep track of the losses per data object
    loss, losses = None, []
    # train the model
    model_rev.train()
    # work through epochs
    for epoch in range(epochs):
        # derive the message as well as the mean field approximation
        msg, msg_intra, log_z_mft = model_rev(edge_index, 1)
        # compute the loss and track it
        loss = -(-log_z_mft + zmft_scalar * torch.trace(torch.mm(msg, torch.t(model_rev.gex))) + zmft_scalar * torch.trace(torch.mm(msg_intra, torch.t(model_rev.gex))) )
        losses.append(loss.detach().numpy()[0][0])
        # derive the gradients, update, and clear
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        # repeatedly force a normalization
        model_rev.conv1.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.conv1.lin.weight), requires_grad=True)
        model_rev.lin.weight = torch.nn.Parameter(normalize_g2g(model_rev.lin.weight), requires_grad=True)
        optimizer = torch.optim.SGD(model_rev.parameters(), lr=learning_rate, momentum=0)
        
    # create the plot
    if plot:
        fig, ax = plt.subplots(figsize=[6, 4])
        ax.grid(False)
        ax.plot(losses, lw=2, color='#fe86a4')
        ax.set_xlim(0, epochs)
        vmin, vmax = min(min(losses), 0), max(losses)
        vstep = (vmax - vmin) * 0.01
        ax.set_ylim(vmin-vstep, vmax+vstep)
        ax.set(xlabel='epochs', ylabel='loss')
    
    # retrieve the data
    obs_g2g_ccc = model_rev.conv1.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_ccc, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)
    obs_g2g_intra = model_rev.lin.weight.clone().detach().numpy()
    if plot:
        g = sns.clustermap(obs_g2g_intra, cmap='seismic', row_cluster=False, col_cluster=False, vmin=-1, vmax=1,
                           figsize=[1+n_genes*0.5, 1+n_genes*0.5], dendrogram_ratio=0.1, cbar_pos=(-0.1, 1, .02, .12))
        g.ax_heatmap.grid(False)
        g.ax_cbar.grid(False)
        g.ax_heatmap.tick_params(labelrotation=0)

    return losses, obs_g2g_ccc, obs_g2g_intra

# %%
def run_sim(params):
    # unpack the parameters
    n_x, n_y, n_genes, learning_rate, variability, seed, epochs = params
    # set the seed
    np.random.seed(seed)
    # define the input g2g
    input_g2g = gen_g2g(n_genes)
    # run the simulation
    losses_scc, input_gex, output_gex, exp_g2g = run_scc(input_g2g, params)

    # define results from ccc
    losses_ccc, obs_g2g_ccc, obs_g2g_intra = run_ccc_from_scc(output_gex, params)
    obs_g2g = obs_g2g_ccc.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_ccc = results.copy()

    # define results from ccc
    obs_g2g = obs_g2g_intra.copy()
    # instantiate a series of the results
    results = pd.Series()
    results.loc['loss_scc'] = losses_scc[-1]
    results.loc['loss_ccc'] = losses_ccc[-1]
    
    # derive the correlation (from ccc)
    rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
    results.loc['spearman_ccc_out_vs_scc_in.r'] = rho
    results.loc['spearman_ccc_out_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(output_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_scc_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_scc_gex_corr_vs_scc_in.p'] = pval
    
    # derive the correlation (correlations of the gex)
    gex_corr = pd.DataFrame(input_gex).corr(method='spearman').values
    rho, pval = ss.spearmanr(gex_corr.flatten(), exp_g2g.flatten())
    results.loc['spearman_in_gex_corr_vs_scc_in.r'] = rho
    results.loc['spearman_in_gex_corr_vs_scc_in.p'] = pval
    
    # name it based on the seed
    results.name = f'seed_{seed}'
    results_intra = results.copy()
    
    return results_ccc, results_intra, losses_scc, losses_ccc

# %%
import multiprocessing as mp
from tqdm import tqdm
# loop through zmft scalar values
df_stats = []
zmft_scalar = 1e-1
for variability in np.arange(0, 5+.5, .5):
    # define the parameters
    n_x, n_y, n_genes = 10, 10, 4
    learning_rate = 1e-1
    epochs = 50
    # define the parameters
    n_sims = 100
    params_list = [[n_x, n_y, n_genes, learning_rate, variability, seed, epochs] for seed in range(n_sims)]
    # run the simulations
    results_list = []
    with mp.Pool(5) as pool:
        for results in tqdm(pool.imap(run_sim, params_list), total=n_sims):
            results_list.append(results)

    # define the order of the metrics
    order = ['loss_scc','loss_ccc',
             'spearman_ccc_out_vs_scc_in.r','spearman_ccc_out_vs_scc_in.p',
             'spearman_scc_gex_corr_vs_scc_in.r','spearman_scc_gex_corr_vs_scc_in.p',
             'spearman_in_gex_corr_vs_scc_in.r','spearman_in_gex_corr_vs_scc_in.p',]
    results_ccc = pd.concat([el[0] for el in results_list], axis=1).loc[order]
    results_intra = pd.concat([el[1] for el in results_list], axis=1).loc[order]

    # define the things we wish to plot
    plotters = [['spearman.r', 'value', ['in-gex-corr','ccc-out']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','ccc-out']],
                ['spearman.r', 'value', ['in-gex-corr','scc-gex-corr']],
                ['spearman.p', 'nlog10p1en4_value', ['in-gex-corr','scc-gex-corr']]]

    # melt the dataframe into a plottable function (complete this for CCC as before)
    data = results_ccc.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    df_stat = pd.DataFrame(columns=['metric','value','dataset0','dataset1','pval','diff','source'])
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'ccc'

    # melt the dataframe into a plottable function (complete this for intra for newly defined method)
    data = results_intra.reset_index().melt(id_vars='index')
    data['dataset'] = data['index'].apply(lambda x: '_'.join(x.split('_')[1:]).split('_vs_')[0]).str.replace('_','-')
    data['metric'] = data['index'].apply(lambda x: x.split('_')[0]+'.'+x.split('.')[-1])
    data['nlog10p1en4_value'] = -np.log10(data['value'].astype(float)+1e-4)
    # run through all of the plots
    for metric, value, datasets in plotters:
        # derive the values
        x1 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[0]), value].reset_index().iloc[:, 1]
        x2 = data.loc[(data['metric'] == metric)&(data['dataset'] == datasets[1]), value].reset_index().iloc[:, 1]
        mask = (~x1.isna()) & (~x2.isna())
        x1, x2 = x1.loc[mask], x2.loc[mask]
        for idx in x1.index:
            ax.plot(datasets, [x1.loc[idx], x2.loc[idx]], color='k', lw=0.5, alpha=0.5, zorder=1)
        # derive the p-value
        pval = ss.wilcoxon(x1, x2)[1]
        diff = np.mean(x1) - np.mean(x2)
        df_stat.loc[df_stat.shape[0]] = metric, value, datasets[0], datasets[1], pval, diff, 'intra'
    df_stat['variability'] = variability
    df_stats.append(df_stat)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.57it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 13.84it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.47it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  16%|██████▋                                   | 16/100 [00:00<00:04, 18.64it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.15it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.39it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.61it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 20.60it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 20.67it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 20.48it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 20.55it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 20.46it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 20.63it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.57it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:25,  3.87it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:04, 18.86it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 19.50it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 19.88it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 19.66it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 19.95it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 19.89it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 20.05it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 20.93it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.07it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.17it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:24,  3.97it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 13.98it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.32it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.01it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.48it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.66it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.83it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.10it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 20.86it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.07it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 20.99it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 20.90it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 20.91it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 21.06it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.29it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.94it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.40it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.57it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 20.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.50it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.74it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.81it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 20.28it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 20.63it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 20.96it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 20.86it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.06it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.24it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.29it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 21.22it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 20.96it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 20.85it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.09it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.75it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:25,  3.88it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.23it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.99it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.48it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.75it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.77it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 20.71it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 20.76it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 20.99it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 20.80it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 20.90it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 20.95it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 20.83it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 20.79it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 21.09it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.04it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.36it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.74it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.14it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.16it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.93it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.55it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 21.10it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.11it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.04it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.24it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.36it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.46it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.28it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 21.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.06it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  80%|█████████████████████████████████▌        | 80/100 [00:03<00:00, 23.68it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  83%|██████████████████████████████████▊       | 83/100 [00:04<00:00, 22.53it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 20.17it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 20.21it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.55it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   1%|▍                                          | 1/100 [00:00<00:24,  4.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#   6%|██▌                                        | 6/100 [00:00<00:06, 13.85it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.31it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.87it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.49it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.83it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.68it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# ...
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.00it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.46it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.92it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 20.93it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  46%|███████████████████▎                      | 46/100 [00:02<00:02, 21.04it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.09it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.18it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 20.93it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 20.87it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 21.32it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 21.17it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  86%|████████████████████████████████████      | 86/100 [00:04<00:00, 21.23it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 21.17it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  96%|████████████████████████████████████████▎ | 96/100 [00:04<00:00, 21.23it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.88it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   6%|██▌                                        | 6/100 [00:00<00:06, 14.16it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  11%|████▌                                     | 11/100 [00:00<00:05, 17.09it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  21%|████████▊                                 | 21/100 [00:01<00:03, 19.99it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  26%|██████████▉                               | 26/100 [00:01<00:03, 20.28it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  31%|█████████████                             | 31/100 [00:01<00:03, 20.75it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  36%|███████████████                           | 36/100 [00:01<00:03, 20.85it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  41%|█████████████████▏                        | 41/100 [00:02<00:02, 21.03it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  51%|█████████████████████▍                    | 51/100 [00:02<00:02, 21.09it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  56%|███████████████████████▌                  | 56/100 [00:02<00:02, 21.19it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  61%|█████████████████████████▌                | 61/100 [00:03<00:01, 21.23it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  66%|███████████████████████████▋              | 66/100 [00:03<00:01, 21.11it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  71%|█████████████████████████████▊            | 71/100 [00:03<00:01, 20.90it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  76%|███████████████████████████████▉          | 76/100 [00:03<00:01, 20.95it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  81%|██████████████████████████████████        | 81/100 [00:04<00:00, 20.84it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
#  91%|██████████████████████████████████████▏   | 91/100 [00:04<00:00, 20.83it/s]/loc/scratch/7949135/ipykernel_16759/2236338304.py:20: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# /loc/scratch/7949135/ipykernel_16759/2236338304.py:48: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   rho, pval = ss.spearmanr(obs_g2g.flatten(), exp_g2g.flatten())
# 100%|█████████████████████████████████████████| 100/100 [00:04<00:00, 20.73it/s]
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/dchen2/.local/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# look at the aggregate
df_stat = pd.concat(df_stats, axis=0)

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'ccc-out')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','variability']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['variability'].round(1).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Standard deviation', ylabel='Input vs. Celcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['variability'].round(1).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Standard deviation', ylabel='Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Standard deviation'),
#  Text(0, 0.5, 'Input vs. Celcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %%
# perform comparison
mask = (df_stat['source'] == 'ccc') & (df_stat['metric'] == 'spearman.r')
mask = mask & (df_stat['value'] == 'value') & (df_stat['dataset1'] == 'scc-gex-corr')
tmp = df_stat.loc[mask, ['dataset0','dataset1','pval','diff','variability']].copy()
# check spearman rho
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['variability'].round(1).astype(str), -tmp['diff'], color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Standard deviation', ylabel='Input vs. Cel->Simcomen via\ndifference of Spearman rho')
# check spearman p-value
fig, ax = plt.subplots(figsize=[4, 4]); ax.grid(False)
ax.bar(tmp['variability'].round(1).astype(str), -np.log10(tmp['pval']), color='salmon', edgecolor='k', linewidth=1.5)
ax.tick_params(axis='x', labelrotation=90)
ax.set(xlabel='Standard deviation', ylabel='Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')
# Out:
# [Text(0.5, 0, 'Standard deviation'),
#  Text(0, 0.5, 'Input vs. Cel->Simcomen via\n-log$_{10}$(p-value) of Spearman rho')]

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for variability in np.arange(0, 5+.5, .5):
    variability = round(variability, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, variability, 0, 50])[-1]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=variability)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Celcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')

# %%
# define hyperparameters
n_genes = 4
fig, ax = plt.subplots(figsize=[6, 4])
ax.grid(False)
for variability in np.arange(0, 5+.5, .5):
    variability = round(variability, 1)
    losses = run_sim([10, 10, n_genes, 1e-1, variability, 0, 50])[-2]
    # create the plot for spleen
    ax.plot(losses, lw=2, label=variability)
ax.set_xlim(0, 50)
vmin, vmax = ax.get_ylim()
vstep = (vmax - vmin) * 0.01
ax.set_ylim(vmin-vstep, vmax+vstep)
ax.set(xlabel='Epochs', ylabel='Loss (Simcomen)', title='Simulation')
ax.legend(bbox_to_anchor=(1.01, .5), bbox_transform=ax.transAxes, frameon=False, loc='center left')
